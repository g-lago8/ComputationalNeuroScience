# %%
#imports here

import numpy as np
import matplotlib.pyplot as plt

# %%
# Parameters for (A) tonic spiking
a = 0.02
b = 0.2
c = -65
d = 6
V = -70  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.25  # Time step
tspan = np.arange(0, 100 + tau, tau)  # Time span
T1 = tspan[-1] / 10  # Time after which the input current changes

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = 14 if t > T1 else 0
    # Update equations
    V = V + tau * (0.04 * V ** 2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
plt.subplot(1, 1, 1)
plt.plot(tspan, VV)
plt.plot([0, T1, T1, max(tspan)], [-90, -90, -80, -80], 'k--')  # Illustrate the input current change
plt.axis([0, max(tspan), -90, 30])
plt.title('(A) tonic spiking')
plt.axis('off')  # Hide axes
plt.show()

# %%
plt.plot(VV, uu)

# %%
# Parameters for (B) phasic spiking
a = 0.02
b = 0.25
c = -65
d = 6
V = -64  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.25  # Time step
tspan = np.arange(0, 200 + tau, tau)  # Time span
T1 = 20  # Time after which the input current changes

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = 0.5 if t > T1 else 0
    # Update equations
    V = V + tau * (0.04 * V ** 2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
plt.subplot(1, 1, 1)
plt.plot(tspan, VV)
plt.plot([0, T1, T1, max(tspan)], [-90, -90, -80, -80], 'k--')  # Illustrate the input current change
plt.axis([0, max(tspan), -90, 30])
plt.title('(B) phasic spiking')
plt.axis('off')  # Hide axes
plt.show()

# %%
# Parameters for (C) tonic bursting
a = 0.02
b = 0.2
c = -50
d = 2
V = -70  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.25  # Time step
tspan = np.arange(0, 220 + tau, tau)  # Time span
T1 = 22  # Time after which the input current changes

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = 15 if t > T1 else 0
    # Update equations
    V = V + tau * (0.04 * V ** 2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
plt.subplot(1, 1, 1)
plt.plot(tspan, VV)
plt.plot([0, T1, T1, max(tspan)], [-90, -90, -80, -80], 'k--')  # Illustrate the input current change
plt.axis([0, max(tspan), -90, 30])
plt.title('(C) tonic bursting')
plt.axis('off')  # Hide axes
plt.show()

# %%
# Parameters for (D) phasic bursting
a = 0.02
b = 0.25
c = -55
d = 0.05
V = -64  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.2  # Time step
tspan = np.arange(0, 200 + tau, tau)  # Time span
T1 = 20  # Time after which the input current changes

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = 0.6 if t > T1 else 0
    # Update equations
    V = V + tau * (0.04 * V ** 2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
plt.subplot(1, 1, 1)
plt.plot(tspan, VV)
plt.plot([0, T1, T1, max(tspan)], [-90, -90, -80, -80], 'k--')  # Illustrate the input current change
plt.axis([0, max(tspan), -90, 30])
plt.title('(D) phasic bursting')
plt.axis('off')  # Hide axes
plt.show()

# %%
# Parameters for (E) mixed mode
a = 0.02
b = 0.2
c = -55
d = 4
V = -70  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.25  # Time step
tspan = np.arange(0, 160 + tau, tau)  # Time span
T1 = tspan[-1] / 10  # Time after which the input current changes

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = 10 if t > T1 else 0
    # Update equations
    V = V + tau * (0.04 * V ** 2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(tspan, VV)
plt.plot([0, T1, T1, max(tspan)], [-90, -90, -80, -80], 'k--')  # Illustrate the input current change
plt.axis([0, max(tspan), -90, 30])
plt.title('(E) mixed mode')
plt.axis('off')  # Hide axes
plt.show()

# %%
# Parameters for (F) spike frequency adaptation
a = 0.01
b = 0.2
c = -65
d = 8
V = -70  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.25  # Time step
tspan = np.arange(0, 85 + tau, tau)  # Time span
T1 = tspan[-1] / 10  # Time after which the input current changes

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = 30 if t > T1 else 0
    # Update equations
    V = V + tau * (0.04 * V ** 2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(tspan, VV)
plt.plot([0, T1, T1, max(tspan)], [-90, -90, -80, -80], 'k--')  # Illustrate the input current change
plt.axis([0, max(tspan), -90, 30])
plt.title('(F) spike frequency adaptation')
plt.axis('off')  # Hide axes
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for (G) Class 1 excitable
a = 0.02
b = -0.1
c = -55
d = 6
V = -60  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.25  # Time step
tspan = np.arange(0, 300 + tau, tau)  # Time span
T1 = 30  # Time after which the input current changes

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable
II = []  # Input current for plotting

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = 0.075 * (t - T1) if t > T1 else 0
    II.append(-90+I)  # Store the input current for plotting
    # Update equations
    V = V + tau * (0.04 * V ** 2 + 4.1 * V + 108 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
# Plot membrane potential
plt.plot(tspan, VV, label="Membrane Potential")
plt.title('(G) Class 1 excitable')
plt.plot(tspan, II, 'k--', label='Input Current')
plt.axis('off')  # Hide axes
plt.show()

# %%
plt.plot(VV, uu)

# %%
# Parameters for (H) Class 2 excitable
a = 0.2
b = 0.26
c = -65
d = 0
V = -64  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.25  # Time step
tspan = np.arange(0, 300 + tau, tau)  # Time span
T1 = 30  # Time after which the input current changes

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable
II = []  # Input current for plotting

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = -0.5 + (0.015 * (t - T1)) if t > T1 else -0.5
    II.append(-90+I)  # Store the input current for plotting
    # Update equations
    V = V + tau * (0.04 * V ** 2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
# Plot membrane potential
plt.plot(tspan, VV, label="Membrane Potential")
plt.title('(H) Class 2 excitable')
plt.plot(tspan, II, 'k--',label="Input Current")
plt.axis('off')  # Hide axes
plt.show()

# %%
plt.plot(VV, uu)

# %%
# Parameters for (I) spike latency

a = 0.02
b = 0.2
c = -65
d = 6
V = -70  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.2  # Time step
tspan = np.arange(0, 100 + tau, tau)  # Time span
T1 = tspan[-1] / 10  # Time after which the input current changes

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = 7.04 if t > T1 and t < T1+3 else 0
    # Update equations
    V = V + tau * (0.04 * V**2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
# Plot membrane potential
plt.plot(tspan, VV, label="Membrane Potential")
plt.title('(I) spike latency')
II = [-90, -90, -80, -80, -90, -90] # Input current for plotting
plt.plot([0, T1, T1, T1+3, T1+3, max(tspan)], II, 'k--',label="Input Current")
plt.axis('off')  # Hide axes
plt.show()

# %%
# Parameters for (J) subthreshold oscillations

a = 0.05
b = 0.26
c = -60
d = 0
V = -62  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.25  # Time step
tspan = np.arange(0, 200 + tau, tau)  # Time span
T1 = tspan[-1] / 10  # Time after which the input current changes

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = 2 if t > T1 and t < T1+5 else 0
    # Update equations
    V = V + tau * (0.04 * V**2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
# Plot membrane potential
plt.plot(tspan, VV, label="Membrane Potential")
plt.title('(J) subthreshold oscillations')
II = [-90, -90, -80, -80, -90, -90] # Input current for plotting
plt.plot([0, T1, T1, T1+5, T1+5, max(tspan)], II, 'k--',label="Input Current")
plt.plot(tspan[220:],-10+20*(VV[220:]-np.mean(VV)), label="Zoomed Membrane Potential oscillations")
plt.axis('off')  # Hide axes
plt.show()

# %%
# Parameters for (K) resonator

a = 0.1
b = 0.26
c = -60
d = -1
V = -62  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.25  # Time step
tspan = np.arange(0, 400 + tau, tau)  # Time span
T1 = tspan[-1] / 10  # Time after which the input current changes
T2 = T1 + 20
T3 = 0.7 * tspan[-1]
T4 = T3 + 40

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = 0.65 if ((t>T1) and (t < T1+4)) or ((t>T2) and (t < T2+4)) or ((t>T3) and (t < T3+4)) or ((t>T4) and (t < T4+4))  else 0
    # Update equations
    V = V + tau * (0.04 * V**2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
# Plot membrane potential
plt.plot(tspan, VV, label="Membrane Potential")
plt.title('(K) resonator')
II = [-90, -90, -80, -80, -90, -90, -80,-80, -90,-90, -80,-80, -90,-90, -80,-80, -90,-90] # Input current for plotting
plt.plot([0, T1, T1, T1+8, T1+8, T2, T2, T2+8, T2+8, T3, T3, T3+8, T3+8, T4, T4, T4+8, T4+8, max(tspan)], II, 'k--',label="Input Current")
plt.axis('off')  # Hide axes
plt.show()

# %%
# Parameters for (L) integrator

a = 0.02
b = -0.1
c = -55
d = 6
V = -60  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.25  # Time step
tspan = np.arange(0, 100 + tau, tau)  # Time span
T1 = tspan[-1] / 11  # Time after which the input current changes
T2 = T1 + 5
T3 = 0.7 * tspan[-1]
T4 = T3 + 10

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = 9 if ((t>T1) and (t < T1+2)) or ((t>T2) and (t < T2+2)) or ((t>T3) and (t < T3+2)) or ((t>T4) and (t < T4+2))  else 0
    # Update equations
    V = V + tau * (0.04 * V**2 + 4.1 * V + 108 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
# Plot membrane potential
plt.plot(tspan, VV, label="Membrane Potential")
plt.title('(L) integrator')
II = [-90, -90, -80, -80, -90, -90, -80,-80, -90,-90, -80,-80, -90,-90, -80,-80, -90,-90] # Input current for plotting
plt.plot([0, T1, T1, T1+2, T1+2, T2, T2, T2+2, T2+2, T3, T3, T3+2, T3+2, T4, T4, T4+2, T4+2, max(tspan)], II, 'k--',label="Input Current")
plt.axis('off')  # Hide axes
plt.show()

# %%
# Parameters for (M) rebound spike

a = 0.03
b = 0.25
c = -60
d = 4
V = -64  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.2  # Time step
tspan = np.arange(0, 200 + tau, tau)  # Time span
T1 = 20  # Time after which the input current changes

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = -15 if (t>T1) and (t < T1+5)  else 0
    # Update equations
    V = V + tau * (0.04 * V**2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
# Plot membrane potential
plt.plot(tspan, VV, label="Membrane Potential")
plt.title('(M) rebound spike')
II = [-85, -85, -90, -90, -85,-85] # Input current for plotting
plt.plot([0, T1, T1, T1+5, T1+5, max(tspan)], II, 'k--',label="Input Current")
plt.axis('off')  # Hide axes
plt.show()

# %%
# Parameters for (N) rebound burst

a = 0.03
b = 0.25
c = -52
d = 0
V = -64  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.2  # Time step
tspan = np.arange(0, 200 + tau, tau)  # Time span
T1 = 20  # Time after which the input current changes

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = -15 if (t>T1) and (t < T1+5)  else 0
    # Update equations
    V = V + tau * (0.04 * V**2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
# Plot membrane potential
plt.plot(tspan, VV, label="Membrane Potential")
plt.title('(N) rebound burst')
II = [-85, -85, -90, -90, -85,-85] # Input current for plotting
plt.plot([0, T1, T1, T1+5, T1+5, max(tspan)], II, 'k--',label="Input Current")
plt.axis('off')  # Hide axes
plt.show()

# %%
# Parameters for (O) threshold variability

a = 0.03
b = 0.25
c = -60
d = 4
V = -64  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.25  # Time step
tspan = np.arange(0, 100 + tau, tau)  # Time span

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    if ((t>10) and (t < 15)) or ((t>80) and (t < 85)):
        I = 1
    elif (t>70) and (t < 75):
        I = -6
    else:
        I=0
    # Update equations
    V = V + tau * (0.04 * V**2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
# Plot membrane potential
plt.plot(tspan, VV, label="Membrane Potential")
plt.title('(O) threshold variability')
II = [-85, -85, -80, -80, -85, -85, -90, -90,-85, -85, -80, -80, -85,-85] # Input current for plotting
plt.plot([0, 10, 10, 15, 15, 70, 70, 75, 75, 80, 80, 85, 85, max(tspan)], II, 'k--',label="Input Current")
plt.axis('off')  # Hide axes
plt.show()

# %%
# Parameters for (P) bistability

a = 0.1
b = 0.26
c = -60
d = 0
V = -61  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.25  # Time step
tspan = np.arange(0, 300 + tau, tau)  # Time span
T1 = tspan[-1]/8
T2 = 216

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable
Is=[]
# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    if ((t>T1) and (t < T1+5)) or ((t>T2) and (t < T2+5)):
        I = 1.24
    else:
        I = 0.24
    Is.append(I)
    # Update equations
    V = V + tau * (0.04 * V**2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
# Plot membrane potential
plt.plot(tspan, VV, label="Membrane Potential")
plt.title('(P) bistability')
II = [-90, -90, -80, -80, -90, -90, -80, -80, -90, -90] # Input current for plotting
plt.plot([0, T1, T1, T1+5, T1+5, T2, T2, T2+5, T2+5, max(tspan)], II, 'k--',label="Input Current")
plt.axis('off')  # Hide axes
plt.show()

# %%
plt.plot(VV,uu)

# %%
print(np.where(np.array(Is)>0.4))
print(np.max(Is))
plt.plot(Is)
# Out:
# (array([151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163,
#        164, 165, 166, 167, 168, 169, 865, 866, 867, 868, 869, 870, 871,
#        872, 873, 874, 875, 876, 877, 878, 879, 880, 881, 882, 883],
#       dtype=int64),)
# 1.24

# %%
# Parameters for (Q) Depolarising After-Potential

a = 1
b = 0.2
c = -60
d = -21
V = -70  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.1  # Time step
tspan = np.arange(0, 50 + tau, tau)  # Time span
T1 = 10

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = 20 if np.abs(t-T1)<1  else 0
    # Update equations
    V = V + tau * (0.04 * V**2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
# Plot membrane potential
plt.plot(tspan, VV, label="Membrane Potential")
plt.title('(Q) Depolarising After-Potential')
II = [-90, -90, -80, -80, -90, -90] # Input current for plotting
plt.plot([0, T1-1, T1-1, T1+1, T1+1, max(tspan)], II, 'k--',label="Input Current")
plt.axis('off')  # Hide axes
plt.show()

# %%
# Parameters for (R) accomodation

a = 0.02
b = 1
c = -55
d = 4
V = -65  # Initial membrane potential
u = -16  # Initial recovery variable
tau = 0.5  # Time step
tspan = np.arange(0, 400 + tau, tau)  # Time span

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable
II = []  # Input current for plotting

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    if (t < 200):
        I = t / 25
    elif t < 300:
        I = 0
    elif  t < 312.5:
        I = (t-300) / 12.5 * 4
    else:
        I = 0
    # Update equations
    V = V + tau * (0.04 * V**2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * (V + 65))
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)
    II.append(I * 1.5 - 90)

# Plotting
plt.figure(figsize=(12, 6))
# Plot membrane potential
plt.plot(tspan, VV, label="Membrane Potential")
plt.title('(R) accomodation')
#II = [-90, -90, -80, -80, -90, -90] # Input current for plotting
plt.plot(tspan,II, 'k--',label="Input Current")
plt.axis('off')  # Hide axes
plt.show()

# %%
# Parameters for (S) inhibition induced spiking

a = -0.02
b = -1
c = -60
d = 8
V = -63.8  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.5  # Time step
tspan = np.arange(0, 350 + tau, tau)  # Time span

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = 80 if (t < 50) or (t>250)  else 75
    # Update equations
    V = V + tau * (0.04 * V**2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
# Plot membrane potential
plt.plot(tspan, VV, label="Membrane Potential")
plt.title('(S) inhibition induced spiking')
II = [-80, -80, -90, -90, -80, -80] # Input current for plotting
plt.plot([0, 50, 50, 250, 250, max(tspan)], II, 'k--',label="Input Current")
plt.axis('off')  # Hide axes
plt.show()

# %%
# Parameters for (T) inhibition induced bursting

a = -0.026
b = -1
c = -45
d = -2
V = -63.8  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.5  # Time step
tspan = np.arange(0, 350 + tau, tau)  # Time span

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = 80 if (t < 50) or (t>250)  else 75
    # Update equations
    V = V + tau * (0.04 * V**2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
# Plot membrane potential
plt.plot(tspan, VV, label="Membrane Potential")
plt.title('(T) inhibition induced bursting')
II = [-80, -80, -90, -90, -80, -80] # Input current for plotting
plt.plot([0, 50, 50, 250, 250, max(tspan)], II, 'k--',label="Input Current")
plt.axis('off')  # Hide axes
plt.show()

# %%
a = -0.026
b = -1
c = -45
d = -2
V = -63.8  # Initial membrane potential
u = b * V  # Initial recovery variable
tau = 0.8  # Time step
tspan = np.arange(0, 350 + tau, tau)  # Time span

# Initialize lists to store the membrane potential (V) and recovery variable (u) over time
VV = []  # Membrane potential
uu = []  # Recovery variable

# Simulation loop
for t in tspan:
    # Apply input current based on the condition
    I = 80 if (t < 50) or (t>250)  else 75
    # Update equations
    V = V + tau * (0.04 * V**2 + 5 * V + 140 - u + I)
    u = u + tau * a * (b * V - u)
    # Reset condition
    if V > 30:
        VV.append(30)
        V = c
        u = u + d
    else:
        VV.append(V)
    uu.append(u)

# Plotting
plt.figure(figsize=(12, 6))
# Plot membrane potential
plt.plot(tspan, VV, label="Membrane Potential")
plt.title('(T) inhibition induced bursting')
II = [-80, -80, -90, -90, -80, -80] # Input current for plotting
plt.plot([0, 50, 50, 250, 250, max(tspan)], II, 'k--',label="Input Current")
plt.axis('off')  # Hide axes
plt.show()

# %%
# define a dictionary to store the parameters for each neuron model
param_dict = {
    'Tonic Spiking': {'a': 0.02, 'b': 0.2, 'c': -50, 'd': 2, 'V': -70, 'u': -14, 'tau': 0.25, 'tspan': np.arange(0, 200 + 0.25, 0.25), 'T1': 22},
    'Phasic Spiking': {'a': 0.02, 'b': 0.25, 'c': -60, 'd': 6, 'V': -64, 'u': -14, 'tau': 0.2, 'tspan': np.arange(0, 200 + 0.2, 0.2), 'T1': 20},
    'Tonic Bursting': {'a': 0.02, 'b': 0.2, 'c': -50, 'd': 2, 'V': -70, 'u': -14, 'tau': 0.25, 'tspan': np.arange(0, 220 + 0.25, 0.25), 'T1': 22},
    'Phasic Bursting': {'a': 0.02, 'b': 0.25, 'c': -64, 'd': 0.05, 'V': -64, 'u': -14, 'tau': 0.2, 'tspan': np.arange(0, 200 + 0.2, 0.2), 'T1': 20},
    'Mixed Mode': {'a': 0.02, 'b': 0.2, 'c': -55, 'd': 4, 'V': -70, 'u': -14, 'tau': 0.25, 'tspan': np.arange(0, 160 + 0.25, 0.25), 'T1': 16},
    'Spike Frequency Adaptation': {'a': 0.01, 'b': 0.2, 'c': -65, 'd': 8, 'V': -70, 'u': -14, 'tau': 0.25, 'tspan': np.arange(0, 85 + 0.25, 0.25), 'T1': 8},
    'Class 1 excitable': {'a': 0.02, 'b': -0.1, 'c': -55, 'd': 6, 'V': -60, 'u': -6, 'tau': 0.25, 'tspan': np.arange(0, 300 + 0.25, 0.25), 'T1': 30},
    'Class 2 excitable': {'a': 0.2, 'b': 0.26, 'c': -65, 'd': 0, 'V': -64, 'u': -6, 'tau': 0.25, 'tspan': np.arange(0, 300 + 0.25, 0.25), 'T1': 30},
    'Spike Latency': {'a': 0.02, 'b': 0.2, 'c': -65, 'd': 6, 'V': -70, 'u': -14, 'tau': 0.2, 'tspan': np.arange(0, 100 + 0.2, 0.2), 'T1': 10},
    'Subthreshold Oscillations': {'a': 0.05, 'b': 0.26, 'c': -60, 'd': 0, 'V': -62, 'u': -16, 'tau': 0.25, 'tspan': np.arange(0, 200 + 0.25, 0.25), 'T1': 20},
    'Resonator': {'a': 0.1, 'b': 0.26, 'c': -60, 'd': -1, 'V': -62, 'u': -16, 'tau': 0.25, 'tspan': np.arange(0, 400 + 0.25, 0.25), 'T1': 40},
    'Integrator': {'a': 0.02, 'b': -0.1, 'c': -55, 'd': 6, 'V': -60, 'u': -6, 'tau': 0.25, 'tspan': np.arange(0, 100 + 0.25, 0.25), 'T1': 10},
    'Rebound Spike': {'a': 0.03, 'b': 0.25, 'c': -60, 'd': 4, 'V': -64, 'u': -16, 'tau': 0.2, 'tspan': np.arange(0, 200 + 0.2, 0.2), 'T1': 20},
    'Rebound Burst': {'a': 0.03, 'b': 0.25, 'c': -52, 'd': 0, 'V': -64, 'u': -16, 'tau': 0.2, 'tspan': np.arange(0, 200 + 0.2, 0.2), 'T1': 20},
    'Threshold Variability': {'a': 0.03, 'b': 0.25, 'c': -60, 'd': 4, 'V': -64, 'u': -16, 'tau': 0.25, 'tspan': np.arange(0, 100 + 0.25, 0.25)},
    'Bistability': {'a': 0.1, 'b': 0.26, 'c': -60, 'd': 0, 'V': -61, 'u': -16, 'tau': 0.25, 'tspan': np.arange(0, 300 + 0.25, 0.25)},
    'Depolarising After-Potential': {'a': 1, 'b': 0.2, 'c': -60, 'd': -21, 'V': -70, 'u': -14, 'tau': 0.1, 'tspan': np.arange(0, 50 + 0.1, 0.1), 'T1': 10},
    'Accomodation': {'a': 0.02, 'b': 1, 'c': -55, 'd': 4, 'V': -65, 'u': -16, 'tau': 0.5, 'tspan': np.arange(0, 400 + 0.5, 0.5)},
    'Inhibition Induced Spiking': {'a': -0.02, 'b': -1, 'c': -60, 'd': 8, 'V': -63.8, 'u': -16, 'tau': 0.5, 'tspan': np.arange(0, 350 + 0.5, 0.5)},
    'Inhibition Induced Bursting': {'a': -0.026, 'b': -1, 'c': -45, 'd': -2, 'V': -63.8, 'u': -16, 'tau': 0.5, 'tspan': np.arange(0, 350 + 0.5, 0.5)}
}
